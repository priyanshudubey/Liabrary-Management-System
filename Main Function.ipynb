# %%
import pickle
import getpass
from sys import exit
from Books import *
from Faculty import *
from students import *
from admin import *

class main():
    '''************WELCOME  TO  LIBRARY  MANAGEMENT  SYSTEM****************'''
    def __init__(self):
        self.pwd="liabrary"
        
    def login(self):
        ch=9
        while(ch!=0):
            print("\nYou are:\n1. Student\n2. Faculty\n3. Admin\n0. Exit")
            ch=int(input("Enter your choice :"))
            if (ch==1):
                ch1=9
                while(ch!=0):
                    s=Students()
                    print("\n1.Display Profile\n2.View Issued Book\n3.Check fine\n4.Display All Books\n0.Exit")
                    ch1=int(input("Enter your choice:"))
                    if ch1==1 :
                        s.profile()
                    elif (ch1==2) :
                        s.View_issued_book()
                    elif (ch1==3) :
                        s.check_fine()
                    elif (ch1==4) :
                        s.display_book()
                    elif ch1==0:
                        break
                    else:
                        print("Wrong Input!!!")
            
            elif ch==2:
                ch1=9
                while(ch!=0):
                    s=Faculty()
                    print("\n1.Display Profile\n2.View Issued Book\n3.Display All Books\n0.Exit")
                    ch1=int(input("Enter your choice:"))
                    if (ch1==1) :
                        s.profile()
                    elif (ch1==2) :
                        s.View_issued_book()
                    elif (ch1==3) :
                        s.display_book()
                    elif ch1==0:
                        break
                    else:
                        print("Wrong Input!!!")
            
            elif ch==3:
                ch1=100
                while(ch!=0):
                    print("\nWelcome Admin!!")
                    p=getpass.getpass("Enter your password or 0 to exit:")
                    if p=='0':
                        break
                    if p==self.pwd:
                        a=admin()
                        print("\n1.Add Book\n2.Display Book\n3.Remove Book\n4.Add Student Record\n5.Display Student Record\n6.Remove Student record\n7.Add Faculty Record\n8.Display Faculty record\n9.Remove faculty record\n10.Issue\n11.Show Issued Details\n12.Check Fine\n0.Exit")
                        ch1=int(input("Enter your choice:"))
                        if (ch1==1):
                            a.add_book()
                        elif (ch1==2):
                            a.display_book()
                        elif (ch1==3):
                            a.remove_book()
                        elif (ch1==4):
                            a.add_student()
                        elif (ch1==5):
                            a.display_student()
                        elif (ch1==6):
                            a.remove_student()
                        elif (ch1==7):
                            a.add_faculty()
                        elif (ch1==8):
                            a.display_faculty()
                        elif (ch1==9):
                            a.remove_faculty()
                        elif (ch1==10):
                            ch2=9
                            while(ch2!=0):
                                print("\n1.Student\n2.Faculty\n0.Exit")
                                ch2=int(input("Enter your choice:"))
                                if (ch2==1):
                                    a.issue_book_student()
                                elif (ch2==2):
                                    a.issue_book_faculty()
                                elif(ch2==0):
                                    break
                                else:
                                    print("Wrong input")
                        elif (ch1==11):
                            ch2=9
                            while(1):
                                print("\n1.Student\n2.Faculty\n0.Exit")
                                ch2=int(input("Enter your choice:"))
                                if (ch2==1):
                                    a.display_issued_book_student()
                                elif (ch2==2):
                                    a.display_issue_book_faculty()
                                elif (ch2==0):
                                    break
                                else:
                                    print("Wrong input")
                        elif (ch1==12):
                            a.check_fine()
                        elif (ch1==0):
                            break
                        else:
                            print("Wrong Input !!!")
                    else:
                        print("Wrong password!!!")
            elif ch==0:
                print("**********Thank you for using*************")
                break
            else:
                print("Wrong Input!!!!")


m=main()
print(main.__doc__)
m.login()
# Out:
# ************WELCOME  TO  LIBRARY  MANAGEMENT  SYSTEM****************
#
# You are:
# 1. Student
# 2. Faculty
# 3. Admin
# 0. Exit
# Enter your choice :1
#
# 1.Display Profile
# 2.View Issued Book
# 3.Check fine
# 4.Display All Books
# 0.Exit
# Enter your choice:1
# Enter your enrollment number to display your profile:0187cs171108
#
# 1.Display Profile
# 2.View Issued Book
# 3.Check fine
# 4.Display All Books
# 0.Exit
# Enter your choice:1
# Enter your enrollment number to display your profile:0
#
# 1.Display Profile
# 2.View Issued Book
# 3.Check fine
# 4.Display All Books
# 0.Exit
# Enter your choice:0
#
# You are:
# 1. Student
# 2. Faculty
# 3. Admin
# 0. Exit
# Enter your choice :1
#
# 1.Display Profile
# 2.View Issued Book
# 3.Check fine
# 4.Display All Books
# 0.Exit
# Enter your choice:1
# Enter your enrollment number to display your profile:0
#
# 1.Display Profile
# 2.View Issued Book
# 3.Check fine
# 4.Display All Books
# 0.Exit
# Enter your choice:0
#
# You are:
# 1. Student
# 2. Faculty
# 3. Admin
# 0. Exit
# Enter your choice :3
#
# Welcome Admin!!
# Enter your password or $ to exit:········
#
# 1.Add Book
# 2.Display Book
# 3.Remove Book
# 4.Add Student Record
# 5.Display Student Record
# 6.Remove Student record
# 7.Add Faculty Record
# 8.Display Faculty record
# 9.Remove faculty record
# 10.Issue
# 11.Show Issued Details
# 12.Check Fine
# 0.Exit
# Enter your choice:4
# How many Students you want to add in record :1
#
#
#
# 	Enter Record of Student 1:-
# Enter Name of student :priyanshu
# Enter Enrollment number :0187cs171108
# Enter Semester :5
# Enter branch :cse
# Enter phone number :95701759896
# Student Record added successfully
#
# Welcome Admin!!
# Enter your password or $ to exit:········
#
# You are:
# 1. Student
# 2. Faculty
# 3. Admin
# 0. Exit
